# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %% [markdown]
# ### El coste de no invertir, ¿Por qué los europeos pierden poder adquisitivo?

# %% [markdown]
# ### TEMA

# %% [markdown]
# En este analisis me gustaria investigar como afecta la falta de inversion al poder adquisitivo en general, comparando la evolucion de distintos activos financieros, ya sean acciones, indices, bonos o metales, con al ahorro tradicional en el cual se suelen usar cuentas bancarias

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %% [markdown]
# ## Principal Hipotesis
#  No invertir ha supuesto una pérdida de poder adquisitivo frente a la inflacion

# %% [markdown]
# ### Hipotesis Secundarias
# 1. Mantener el dinero en depósitos bancarios ha resultado en una pérdida de poder adquisitivo debido a la inflación
# 2. Los ETFs han ofrecido un balance rentabilidad-riesgo superior al de los bonos y metales preciosos.
# 3. El S&P 500 ha sido uno de los activos más rentables y consistentes a largo plazo, con una volatilidad moderada gracias a su diversificación
# 4. El oro y la plata han funcionado como activos refugio durante periodos de incertidumbre, pero con rentabilidad moderada
# 5. Los bonos del Tesoro a 10 años han ofrecido rentabilidades inferiores a la inflación en muchos periodos

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd

# %%
fuente_1 = "https://www.kaggle.com/datasets/joseserrat/cpi-consumer-price-index-1913-jan-2021-jun"

fuente_2 = "https://www.kaggle.com/datasets/kornilovag94/etfs-bonds-market-dataset"

fuente_3 = "https://www.kaggle.com/datasets/paikim/sp500-stock-price-by-ticker-06-08-202410years"

fuente_4 = "https://www.kaggle.com/datasets/lsind18/daily-london-metal-fix-prices"

fuente_5 = "https://www.kaggle.com/datasets/manish4348/us10-year-bond-yield-1962-2023"

# %%
df_1 = pd.read_csv("Bases de datos EDA\CPI_database.csv", sep = ",")
df_1.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\paumo\AppData\Local\Temp\ipykernel_17268\4093215259.py:1: SyntaxWarning: invalid escape sequence '\C'
#   df_1 = pd.read_csv("Bases de datos EDA\CPI_database.csv", sep = ",")
#    Unnamed: 0  Value
# 0  1913-01-01    9.8
# 1  1913-02-01    9.8
# 2  1913-03-01    9.8
# 3  1913-04-01    9.8
# 4  1913-05-01    9.7

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
df_2 = pd.read_csv("Bases de datos EDA\ETFs_(bonds)_Market_Dataset.csv", sep = ";")
df_2.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\paumo\AppData\Local\Temp\ipykernel_17268\4194871483.py:1: SyntaxWarning: invalid escape sequence '\E'
#   df_2 = pd.read_csv("Bases de datos EDA\ETFs_(bonds)_Market_Dataset.csv", sep = ";")
#          Date PX_LAST PX_OPEN    PX_LOW PX_HIGH  PX_VOLUME  \
# 0  01.01.2008  101,35  101,37    101,35   101,4       1600
# 1  02.01.2008  101,49  101,15    101,15  101,53       7600
# 2  03.01.2008  101,67  101,77    101,67  101,77       2300
# 3  04.01.2008  101,72  101,74  101,6588  101,74       1800
# 4  07.01.2008  101,95  101,86    101,69  101,95      11000
#
#   AVERAGE_BID_ASK_SPREAD_%  VOLUME_TOTAL_PUT  VOLUME_TOTAL_CALL  \
# 0                      NaN               NaN                NaN
# 1                      NaN               NaN                NaN
# 2                      NaN               NaN                NaN
# ...

# %%
df_3 = pd.read_csv("Bases de datos EDA\Metales_preciados_1990-2024.csv", sep = ",")
df_3 .head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\paumo\AppData\Local\Temp\ipykernel_17268\2060694946.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df_3 = pd.read_csv("Bases de datos EDA\Metales_preciados_1990-2024.csv", sep = ",")
#          Date  Gold AM Fix Gold PM Fix Silver Fix Platinum AM Fix  \
# 0  2024-09-09      2496.65      2499.7      28.13           937.0
# 1  2024-09-06      2517.70     2506.15      28.84           931.0
# 2  2024-09-05      2516.85     2509.55      28.72           927.0
# 3  2024-09-04      2474.45     2487.95      28.08           903.0
# 4  2024-09-03      2503.25      2479.8      28.32           923.0
#
#   Platinum PM Fix  Palladium AM Fix Palladium PM Fix
# 0           944.0             925.0            943.0
# 1           934.0             943.0            955.0
# 2           929.0             948.0            945.0
# 3           910.0             935.0            938.0
# ...

# %%
df_4 = pd.read_csv("Bases de datos EDA\SP500_Stock_Price_by_Ticker_06.08.2024(10years).csv", sep = ",")
df_4.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\paumo\AppData\Local\Temp\ipykernel_17268\2435942385.py:1: SyntaxWarning: invalid escape sequence '\S'
#   df_4 = pd.read_csv("Bases de datos EDA\SP500_Stock_Price_by_Ticker_06.08.2024(10years).csv", sep = ",")
#          Date       MDLZ          CI        ANET        KLAC        PANW  \
# 0  2024-06-07  67.809998  338.100006  296.790008  768.969971  301.899994
# 1  2024-06-06  68.190002  337.910004  296.570007  779.260010  295.929993
# 2  2024-06-05  67.980003  334.179993  297.559998  784.969971  295.410004
# 3  2024-06-04  68.089996  337.059998  293.179993  750.559998  290.089996
# 4  2024-06-03  67.349998  340.089996  296.390015  754.150024  294.480011
#
#           PLD         ADP         MMC         ADI  ...        MAS        NDSN  \
# 0  110.199997  252.320007  209.990005  234.770004  ...  66.029999  226.149994
# ...

# %%
df_5 = pd.read_csv("Bases de datos EDA\US10year_bondyield_1962-2023.csv",  sep = ",")
df_5.head()
# Out:
#   Cell In[48], line 1
#     df_5 = pd.read_csv("Bases de datos EDA\US10year_bondyield_1962-2023.csv",  sep = ",")
#                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 18-19: truncated \UXXXXXXXX escape
